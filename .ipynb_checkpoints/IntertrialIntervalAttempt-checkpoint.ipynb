# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from preprocessingFunctions import loadData

# %%
#%% load data
Adat,Mdat = loadData('/home/esther/Documents/science/BehavioralTraining/')
# Out:
# /home/esther/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:782: FutureWarning: The 'tupleize_cols' argument has been deprecated and will be removed in a future version. Column tuples will then always be converted to MultiIndex.
#
#
#   self.options, self.engine = self._clean_options(options, engine)

# %%
Adat.head()
# Out:
# Animal                                1                              \
#                       additional_reward animal_answer reaction_time
# Phase Day Block Trial
# 1     1   1     1                   1.0           1.0        1608.0
#                 2                   4.0           1.0         102.0
#                 3                   2.0           1.0        1103.0
#                 4                   1.0           1.0         783.0
#                 5                   4.0           0.0           0.0
#
# Animal                                                 2                \
#                       reward_size side additional_reward animal_answer
# Phase Day Block Trial
# 1     1   1     1             0.0  0.0               5.0           0.0
#                 2             2.0  1.0               5.0           1.0
#                 3             0.0  0.0               1.0           1.0
#                 4             0.0  0.0               4.0           0.0
# ...

# %%
pd.read_csv('/home/esther/Documents/science/BehavioralTraining/extra/results/CSVresults/ToneTaskMaze/trial_data/Day_6/Block_1/Animal_1.csv')
# Out:
#     trial_nr  side  animal_answer  reaction_time  reward_size  \
# 0          1     0              0            642            2
# 1          2     0              0           1320            2
# 2          3     1              1           1143            2
# 3          4     1              1            711            2
# 4          5     0              0            910            2
# 5          6     1              1              0            2
# 6          7     0              1            930            0
# 7          8     0              0            670            2
# 8          9     0              0           1130            2
# 9         10     1              1            356            2
# 10        11     1              1            735            2
# 11        12     0              0            981            2
# 12        13     1              1            782            2
# 13        14     1              1           1357            2
# ...

# %%
pd.read_csv('/home/esther/Documents/science/BehavioralTraining/extra/results/CSVresults/ToneTaskAna2/trial_data/Day_11/Block_4/Animal_1.csv')
# Out:
#     trial_nr  flavour  animal_answer  reaction_time  reward_size  \
# 0          1        0              0           1138            1
# 1          2        1              1              0            2
# 2          3        1              0           1932            0
# 3          4        0              0            298            2
# 4          5        1              1              0            2
# 5          6        1              1             78            2
# 6          7        1              1              0            2
# 7          8        0              0           1028            1
# 8          9        0              0            346            2
# 9         10        0              0            385            2
# 10        11        1              1             26            2
# 11        12        1              0            885            0
# 12        13        1              1            623            2
# ...

# %%
pd.read_csv('/home/esther/Documents/science/BehavioralTraining/extra/results/Raw/TT1/trial_data/Day_7/Block_3/Animal_3.csv')
# Out:
#    trial_nr  flavour  animal_answer  reaction_time  reward_size  \
# 0         1        0              0           1214            0
# 1         2        1              0           1979            0
# 2         3        1              1              0            0
# 3         4        1              0           4205            0
# 4         5        0              1              0            0
# 5         6        1              1              0            0
# 6         7        1              1              0            0
# 7         8        0              0            885            0
# 8         9        0              1           2660            0
# 9        10        1              1            160            0
#
#    additional_reward aditional_info
# 0                  1
# 1                  0
# 2                  5
# 3                  0
# 4                  0
# 5                  5
# 6                  1
# 7                  4
# 8                  0
# 9                  6
